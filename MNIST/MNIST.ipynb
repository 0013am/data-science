# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
df=pd.read_csv(r'C:\Users\91870\Desktop\data\train.csv\train.csv')
data=df.values
np.random.shuffle(data)
y=data[:,:1]
d=data[:,1:]

# %%
idx=13
#plt.figure(figsize=(7,7))
data=d[idx].reshape(28,28)
plt.imshow(data,interpolation=None,cmap='gray')
plt.show()
y[idx]
# Out:
# array([4], dtype=int64)

# %% [markdown]
# -  split the data for train and test model

# %%
split=int(0.80*d.shape[0])
X_train=d[:split, :]
Y_train=y[:split]
X_test=d[split:,:]
Y_test=y[split:]

# %%
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.imshow(X_train[i+1].reshape(28,28),cmap='gray')
    plt.title(Y_train[i+1])
    plt.axis('off')
